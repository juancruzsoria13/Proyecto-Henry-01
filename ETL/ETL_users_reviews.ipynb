# %%
import pandas as pd
from pandas import json_normalize
import json
import ast as ast
import re

# %%
path=r"C:\Users\juanc.DESKTOP-LGMDQP1\OneDrive\Documentos\Proyecto Henry 01\Datos\australian_user_reviews.json"

# %%
lista=[]

with open(path,encoding="UTF-8  ") as archivo:
    for linea in archivo.readlines():
        lista.append(ast.literal_eval(linea))

# %%
df_reviews=pd.DataFrame(lista)
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
df_reviews=df_reviews.drop(["user_url"],axis=1)

# %%
df_reviews= df_reviews.explode("reviews")

# %%
df_reviews
# Out:
#                  user_id                                            reviews
# 0      76561197970982479  {'funny': '', 'posted': 'Posted November 5, 20...
# 0      76561197970982479  {'funny': '', 'posted': 'Posted July 15, 2011....
# 0      76561197970982479  {'funny': '', 'posted': 'Posted April 21, 2011...
# 1                js41637  {'funny': '', 'posted': 'Posted June 24, 2014....
# 1                js41637  {'funny': '', 'posted': 'Posted September 8, 2...
# ...                  ...                                                ...
# 25797  76561198312638244  {'funny': '', 'posted': 'Posted July 10.', 'la...
# 25797  76561198312638244  {'funny': '', 'posted': 'Posted July 8.', 'las...
# 25798        LydiaMorley  {'funny': '1 person found this review funny', ...
# 25798        LydiaMorley  {'funny': '', 'posted': 'Posted July 20.', 'la...
# 25798        LydiaMorley  {'funny': '', 'posted': 'Posted July 2.', 'las...
#
# [59333 rows x 2 columns]

# %%
df_solo_reviews=json_normalize(df_reviews["reviews"])

# %%
df_reviews.reset_index(drop=True,inplace=True)

# %%
df_reviews_final=pd.concat((df_reviews.drop(columns=["reviews"]),df_solo_reviews),axis=1)

# %%
columns_to_drop=["posted","last_edited","funny"]
df_reviews_final=df_reviews_final.drop(columns_to_drop, axis=1)

# %%
df_reviews_final
# Out:
#                  user_id item_id  \
# 0      76561197970982479    1250
# 1      76561197970982479   22200
# 2      76561197970982479   43110
# 3                js41637  251610
# 4                js41637  227300
# ...                  ...     ...
# 59328  76561198312638244      70
# 59329  76561198312638244  362890
# 59330        LydiaMorley  273110
# 59331        LydiaMorley     730
# 59332        LydiaMorley     440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# ...

# %%
def extraer_porcentaje(valor):
    if isinstance(valor, str): 
        coincidencia = re.search(r'\((\d+)%\)', valor)
        if coincidencia:
            return coincidencia.group(1)
    return valor


df_reviews_final['helpful'] = df_reviews_final['helpful'].apply(extraer_porcentaje)

# %%
df_reviews_final["helpful"].value_counts()
# Out:
# helpful
# No ratings yet    30168
# 100                9841
# 0                  6112
# 50                 3429
# 67                 1640
#                   ...
# 16                    8
# 2                     5
# 97                    4
# 98                    4
# 34                    3
# Name: count, Length: 100, dtype: int64

# %%
df_reviews_final["helpful"].iloc[3]
# Out:
# '75'

# %%
df_reviews_final
# Out:
#                  user_id item_id         helpful recommend  \
# 0      76561197970982479    1250  No ratings yet      True
# 1      76561197970982479   22200  No ratings yet      True
# 2      76561197970982479   43110  No ratings yet      True
# 3                js41637  251610              75      True
# 4                js41637  227300               0      True
# ...                  ...     ...             ...       ...
# 59328  76561198312638244      70  No ratings yet      True
# 59329  76561198312638244  362890  No ratings yet      True
# 59330        LydiaMorley  273110              50      True
# 59331        LydiaMorley     730  No ratings yet      True
# 59332        LydiaMorley     440  No ratings yet      True
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# 1                   It's unique and worth a playthrough.
# 2      Great atmosphere. The gunplay can be a bit chu...
# ...

# %%
df_reviews_final.to_parquet(r"C:\Users\juanc.DESKTOP-LGMDQP1\OneDrive\Documentos\Proyecto Henry 01\ETL\ETL_users_reviews.parquet",index=False)
